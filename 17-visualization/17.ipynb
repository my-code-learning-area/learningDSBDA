# %% [markdown]
# # Notes
#
# <hr>
#
# ## HIST:
#     df[cols].hist(bins=15, figsize=(10,6))
#
# ## DOT:
#     sn.stripplot(data=df, x="cp", y="trestbps", jitter=True)
#
# ## BAR:
#     df['restecg'].value_counts().plot(kind="bar")
#
# ## LINE:
#     mat.plot(df['trestbps'], color='#3299ff')
#
# ## SCATTER PLOT:
#     sn.scatterplot(data=df, x='chol', y='thalach', hue='target')
#
# ## PIE:
#     df['sex'].value_counts().plot(kind="pie", labels=["male", "female"], autopct='%1.2f%%')
#
# ## BOX:
#     sn.boxplot(data=df, x='age', y='oldpeak')

# %%
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sn

# %%
df = pd.read_csv("heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0      52    1   0       125   212    0        1      168      0      1.0  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # HIST - 1

# %%
cols = ['age', 'chol', 'thalach']
df[cols].hist(bins=15, figsize=(15,10))
mat.tight_layout()

# %% [markdown]
# # DOT - 0

# %%
mat.figure(figsize=(10,6))
sn.stripplot(data=df, x="cp", y="trestbps", jitter=True)
mat.xlabel('cp')
mat.ylabel('trestbps')
mat.plot()
# Out:
# []

# %% [markdown]
# # BAR - 1

# %%
col = 'restecg'
df[col].value_counts().plot(kind="bar")
mat.xlabel(col)
mat.ylabel('Count')
mat.show() ## ?""

# %%
col = 'fbs'
df[col].value_counts().plot(kind="bar")
mat.xlabel(col)
mat.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
col = 'slope'
df[col].value_counts().plot(kind="bar")
mat.xlabel(col)
mat.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Line

# %%
mat.plot(df['trestbps'], color='#3299ff')

# %%
col = 'oldpeak'
mat.plot(df[col])

# %%
col = 'thalach'
mat.plot(df[col])

# %% [markdown]
# # Multivariate analysis using scatter plot

# %%
# for 2 elected cols
sn.scatterplot(data=df, x='chol', y='thalach', hue='target')
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %% [markdown]
# # PIE

# %%
df['sex'].value_counts().plot(kind="pie", labels=["male", "female"], autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # BOX

# %%
sn.boxplot(data=df, x='age', y='oldpeak')
# Out:
# <Axes: xlabel='age', ylabel='oldpeak'>
