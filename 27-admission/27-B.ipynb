# %%
import pandas as pd

# %%
DataFrame=pd.read_csv('Admission_Predict_Ver1.1.csv')
DataFrame
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# # Subset
# ### Required to done by Classes here but not implemented in that way

# %%
Subset1=DataFrame[DataFrame['Chance of Admit ']>=0.85]
Subset1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 5             6        330          115                  5  4.5   3.0  9.34
# 22           23        328          116                  5  5.0   5.0  9.50
# 23           24        334          119                  5  5.0   4.5  9.70
# 24           25        336          119                  5  4.0   3.5  9.80
# ..          ...        ...          ...                ...  ...   ...   ...
# 470         471        320          110                  5  4.0   4.0  9.27
# 472         473        327          116                  4  4.0   4.5  9.48
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
#
#      Research  Chance of Admit
# ...

# %%
Subset2=DataFrame[DataFrame['Chance of Admit ']>0.85]
Subset2
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 5             6        330          115                  5  4.5   3.0  9.34
# 22           23        328          116                  5  5.0   5.0  9.50
# 23           24        334          119                  5  5.0   4.5  9.70
# 24           25        336          119                  5  4.0   3.5  9.80
# ..          ...        ...          ...                ...  ...   ...   ...
# 470         471        320          110                  5  4.0   4.0  9.27
# 472         473        327          116                  4  4.0   4.5  9.48
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
#
#      Research  Chance of Admit
# ...

# %%
Subset2=DataFrame[DataFrame['Chance of Admit ']<=0.85]
Subset2
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 6             7        321          109                  3  3.0   4.0  8.20
# ..          ...        ...          ...                ...  ...   ...   ...
# 492         493        298          101                  4  2.5   4.5  7.69
# 493         494        300           95                  2  3.0   1.5  8.22
# 494         495        301           99                  3  2.5   2.0  8.45
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# # Merge

# %%
Merged=pd.concat([Subset1,Subset2])
Merged
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 5             6        330          115                  5  4.5   3.0  9.34
# 22           23        328          116                  5  5.0   5.0  9.50
# 23           24        334          119                  5  5.0   4.5  9.70
# 24           25        336          119                  5  4.0   3.5  9.80
# ..          ...        ...          ...                ...  ...   ...   ...
# 492         493        298          101                  4  2.5   4.5  7.69
# 493         494        300           95                  2  3.0   1.5  8.22
# 494         495        301           99                  3  2.5   2.0  8.45
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# # Sort

# %%
Sorted1=DataFrame.sort_values('GRE Score')
Sorted1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 377         378        290          100                  1  1.5   2.0  7.56
# 117         118        290          104                  4  2.0   2.5  7.46
# 168         169        293           97                  2  2.0   4.0  7.80
# 79           80        294           93                  1  1.5   2.0  7.36
# 272         273        294           95                  1  1.5   1.5  7.64
# ..          ...        ...          ...                ...  ...   ...   ...
# 81           82        340          120                  4  5.0   5.0  9.50
# 84           85        340          115                  5  4.5   4.5  9.45
# 143         144        340          120                  4  4.5   4.0  9.92
# 384         385        340          113                  4  5.0   5.0  9.74
# 429         430        340          115                  5  5.0   4.5  9.06
#
#      Research  Chance of Admit
# ...

# %%
Sorted2=DataFrame.sort_values('TOEFL Score')
Sorted2
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 368         369        298           92                  1  2.0   2.0  7.88
# 28           29        295           93                  1  2.0   2.0  7.20
# 79           80        294           93                  1  1.5   2.0  7.36
# 411         412        313           94                  2  2.5   1.5  8.13
# 347         348        299           94                  1  1.0   1.0  7.34
# ..          ...        ...          ...                ...  ...   ...   ...
# 81           82        340          120                  4  5.0   5.0  9.50
# 97           98        331          120                  3  4.0   4.0  8.96
# 297         298        320          120                  3  4.0   4.5  9.11
# 143         144        340          120                  4  4.5   4.0  9.92
# 497         498        330          120                  5  4.5   5.0  9.56
#
#      Research  Chance of Admit
# ...

# %%
Sorted2=DataFrame.sort_values('University Rating')
Sorted2
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 438         439        318          110                  1  2.5   3.5  8.54
# 28           29        295           93                  1  2.0   2.0  7.20
# 369         370        301           98                  1  2.0   3.0  8.03
# 139         140        318          109                  1  3.5   3.5  9.12
# 272         273        294           95                  1  1.5   1.5  7.64
# ..          ...        ...          ...                ...  ...   ...   ...
# 133         134        323          112                  5  4.0   4.5  8.78
# 134         135        333          113                  5  4.0   4.0  9.28
# 142         143        331          115                  5  4.0   3.5  9.44
# 151         152        332          116                  5  5.0   5.0  9.28
# 339         340        324          107                  5  3.5   4.0  8.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# # Transpose

# %%
DataFrame.T
# Out:
#                       0       1       2       3       4       5       6    \
# Serial No.           1.00    2.00    3.00    4.00    5.00    6.00    7.00
# GRE Score          337.00  324.00  316.00  322.00  314.00  330.00  321.00
# TOEFL Score        118.00  107.00  104.00  110.00  103.00  115.00  109.00
# University Rating    4.00    4.00    3.00    3.00    2.00    5.00    3.00
# SOP                  4.50    4.00    3.00    3.50    2.00    4.50    3.00
# LOR                  4.50    4.50    3.50    2.50    3.00    3.00    4.00
# CGPA                 9.65    8.87    8.00    8.67    8.21    9.34    8.20
# Research             1.00    1.00    1.00    1.00    0.00    1.00    1.00
# Chance of Admit      0.92    0.76    0.72    0.80    0.65    0.90    0.75
#
#                       7      8       9    ...     490     491     492     493  \
# Serial No.           8.00    9.0   10.00  ...  491.00  492.00  493.00  494.00
# ...

# %% [markdown]
# # Melt

# %%
Melt=pd.melt(DataFrame,id_vars=['GRE Score','TOEFL Score','University Rating'],var_name='Metric',value_name='value')
Melt
# Out:
#       GRE Score  TOEFL Score  University Rating            Metric  value
# 0           337          118                  4        Serial No.   1.00
# 1           324          107                  4        Serial No.   2.00
# 2           316          104                  3        Serial No.   3.00
# 3           322          110                  3        Serial No.   4.00
# 4           314          103                  2        Serial No.   5.00
# ...         ...          ...                ...               ...    ...
# 2995        332          108                  5  Chance of Admit    0.87
# 2996        337          117                  5  Chance of Admit    0.96
# 2997        330          120                  5  Chance of Admit    0.93
# 2998        312          103                  4  Chance of Admit    0.73
# 2999        327          113                  4  Chance of Admit    0.84
#
# [3000 rows x 5 columns]

# %% [markdown]
# # Casting

# %%
Casting=pd.pivot_table(DataFrame,index=['GRE Score','TOEFL Score','University Rating'],values='Chance of Admit ')
Casting
# Out:
#                                          Chance of Admit
# GRE Score TOEFL Score University Rating
# 290       100         1                             0.470
#           104         4                             0.450
# 293       97          2                             0.640
# 294       93          1                             0.460
#           95          1                             0.490
# ...                                                   ...
# 340       113         4                             0.960
#           114         5                             0.900
#           115         5                             0.945
#           120         4                             0.965
#                       5                             0.955
#
# [414 rows x 1 columns]

# %% [markdown]
# # End
