# %%
import pandas as pd

# %%
df = pd.read_csv("adult.csv")
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex
# 0        Never-married        Adm-clerical   Not-in-family   White     Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
## to add columns if csv does not have it

# col=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','target']
# df.columns=col

# %% [markdown]
# # Subset

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
male = df[df['sex']==' Male']
male.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 7   52   Self-emp-not-inc  209642     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex
# 0        Never-married        Adm-clerical   Not-in-family   White   Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
# 7   Married-civ-spouse     Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
female = df[df['sex']==' Female']
female.head()
# Out:
#     age workclass  fnlwgt   education  education-num          marital-status
# 4    28   Private  338409   Bachelors             13      Married-civ-spouse  \
# 5    37   Private  284582     Masters             14      Married-civ-spouse
# 6    49   Private  160187         9th              5   Married-spouse-absent
# 8    31   Private   45781     Masters             14           Never-married
# 12   23   Private  122272   Bachelors             13           Never-married
#
#           occupation    relationship    race      sex  capital-gain
# 4     Prof-specialty            Wife   Black   Female             0  \
# 5    Exec-managerial            Wife   White   Female             0
# 6      Other-service   Not-in-family   Black   Female             0
# 8     Prof-specialty   Not-in-family   White   Female         14084
# 12      Adm-clerical       Own-child   White   Female             0
#
#     capital-loss  hours-per-week  native-country  salary
# ...

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
white = df[df['race']==' White']
white.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 5   37            Private  284582     Masters             14
# 7   52   Self-emp-not-inc  209642     HS-grad              9
#
#         marital-status          occupation    relationship    race      sex
# 0        Never-married        Adm-clerical   Not-in-family   White     Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 5   Married-civ-spouse     Exec-managerial            Wife   White   Female
# 7   Married-civ-spouse     Exec-managerial         Husband   White     Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# # Merge

# %%
concat = pd.concat([male, female])
concat.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 7   52   Self-emp-not-inc  209642     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex
# 0        Never-married        Adm-clerical   Not-in-family   White   Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
# 7   Married-civ-spouse     Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# # Sort

# %%
sort = df.sort_values('age')
sort.head()
# Out:
#        age   workclass  fnlwgt education  education-num  marital-status
# 12318   17     Private  127366      11th              7   Never-married  \
# 6312    17     Private  132755      11th              7   Never-married
# 30927   17     Private  108470      11th              7   Never-married
# 12787   17   Local-gov  308901      11th              7   Never-married
# 25755   17           ?   47407      11th              7   Never-married
#
#            occupation relationship    race      sex  capital-gain
# 12318           Sales    Own-child   White   Female             0  \
# 6312            Sales    Own-child   White     Male             0
# 30927   Other-service    Own-child   Black     Male             0
# 12787    Adm-clerical    Own-child   White   Female             0
# 25755               ?    Own-child   White     Male             0
#
#        capital-loss  hours-per-week  native-country  salary
# 12318             0               8   United-States   <=50K
# ...

# %% [markdown]
# # Transpose

# %%
df.T
# Out:
#                          0                    1                   2
# age                         39                   50                  38  \
# workclass            State-gov     Self-emp-not-inc             Private
# fnlwgt                   77516                83311              215646
# education            Bachelors            Bachelors             HS-grad
# education-num               13                   13                   9
# marital-status   Never-married   Married-civ-spouse            Divorced
# occupation        Adm-clerical      Exec-managerial   Handlers-cleaners
# relationship     Not-in-family              Husband       Not-in-family
# race                     White                White               White
# sex                       Male                 Male                Male
# capital-gain              2174                    0                   0
# capital-loss                 0                    0                   0
# ...

# %% [markdown]
# # Melt

# %%
melt = df.melt(id_vars=['education', 'age'], var_name='Metric', value_name='values')
melt.head()
# Out:
#     education  age     Metric             values
# 0   Bachelors   39  workclass          State-gov
# 1   Bachelors   50  workclass   Self-emp-not-inc
# 2     HS-grad   38  workclass            Private
# 3        11th   53  workclass            Private
# 4   Bachelors   28  workclass            Private

# %% [markdown]
# # Cascade

# %%
cascade = pd.pivot_table(df, index=['workclass', 'occupation'], values='hours-per-week')
cascade
# Out:
#                                  hours-per-week
# workclass    occupation
#  ?            ?                       31.919390
#  Federal-gov  Adm-clerical            40.154574
#               Armed-Forces            40.666667
#               Craft-repair            40.781250
#               Exec-managerial         42.572222
# ...                                         ...
#  Without-pay  Farming-fishing         36.666667
#               Handlers-cleaners       40.000000
#               Machine-op-inspct       25.000000
#               Other-service           55.000000
#               Transport-moving        20.000000
#
# [83 rows x 1 columns]
